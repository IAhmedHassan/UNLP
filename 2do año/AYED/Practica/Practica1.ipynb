// %% [markdown]
// # Práctica 1 - Algoritmos y Estructuras de Datos
// ## Estructuras de control y estructuras de datos básicas en Java. Recursión
//
// **Nota:**
// * Cree un proyecto llamado “AYED” para guardar todas las clases que implemente durante la cursada.
// * Implemente cada ejercicio en un paquete que contenga los números del TP y del ejercicio. Ejemplo `tp1.ejercicio3`
// * Para resolver esta práctica haremos uso de las estructuras de datos array y “listas” provistas por Java: `ArrayList` y `LinkedList`.
//
// ---
//
// ### Ejercicio 1
// Escriba tres métodos de clase (static) que reciban por parámetro dos números enteros (tipo int) a y b e impriman todos los números enteros comprendidos entre a; b (inclusive), uno por cada línea en la salida estándar. Para ello, dentro de una nueva clase escriba un método por cada uno de los siguientes incisos:
// a. Que realice lo pedido con un **for**.
// b. Que realice lo pedido con un **while**.
// c. Que realice lo pedido **sin utilizar estructuras de control iterativas** (for, while, do while).
//
// Por último, escriba en el método de clase `main` el llamado a cada uno de los métodos creados, con valores de ejemplo. En su computadora, ejecute el programa y verifique que se cumple con lo pedido.

// %%
// Resolución Ejercicio 1
public class Ejercicio1 {
    public static void main(String[] args) {
        // Tu código aquí
    }
}

// %% [markdown]
// ---
//
// ### Ejercicio 2
// Escriba un método de clase que dado un número **n** devuelva un nuevo arreglo de tamaño **n** con los **n** primeros múltiplos enteros de **n** mayores o iguales que 1.
// Ejemplo: `f(5) = [5; 10; 15; 20; 25]; f(k) = {n*k donde k : 1..k}`
//
// Agregue al programa la posibilidad de probar con distintos valores de n ingresandolos por teclado, mediante el uso de `System.in`. La clase Scanner permite leer de forma sencilla valores de entrada.

// %%
// Resolución Ejercicio 2
import java.util.Scanner;

public class Ejercicio2 {
    public static void main(String[] args) {
        // Tu código aquí
    }
}

// %% [markdown]
// ---
//
// ### Ejercicio 3
// Creación de instancias mediante el uso del operador **new**:
// a. Cree una clase llamada **Estudiante** con los atributos especificados abajo y sus correspondientes métodos getters y setters: `nombre`, `apellido`, `comision`, `email`, `direccion`.
// b. Cree una clase llamada **Profesor** con los atributos: `nombre`, `apellido`, `email`, `catedra`, `facultad`.
// c. Agregue un método de instancia llamado **tusDatos()** en la clase Estudiante y en la clase Profesor, que retorne un String con los datos de los atributos de las mismas. Para acceder a los valores utilice los getters previamente definidos.
// d. Escriba una clase llamada **Test** con el método main, el cual cree un arreglo con 2 objetos Estudiante, otro arreglo con 3 objetos Profesor, y luego recorra ambos arreglos imprimiendo los valores obtenidos mediante el método tusDatos().
// e. Agregue dos breakpoints y ejecute en modo debug.

// %%
// Resolución Ejercicio 3
public class TestEjercicio3 {
    public static void main(String[] args) {
        // Tu código aquí
    }
}

// Puedes definir las clases Estudiante y Profesor aquí debajo o en celdas separadas

// %% [markdown]
// ---
//
// ### Ejercicio 4
// Pasaje de parámetros en Java
// a. Sin ejecutar el programa en su computadora, sólo analizándolo, indique qué imprime el código provisto en la cátedra para la clase `SwapValores`.
// b. Ejecute el ejercicio en su computadora, y compare su resultado con lo esperado en el inciso anterior.
// c. Inserte un breakpoint en las líneas donde se indica y ejecute en modo debug para comprobar los valores de x, y.

// %%
// Resolución Ejercicio 4
public class SwapValores {
    public static void main(String[] args) {
        // Tu código aquí
    }
}

// %% [markdown]
// ---
//
// ### Ejercicio 5
// Dado un arreglo de valores tipo entero se desea calcular el valor máximo, mínimo, y promedio en un único método. Escriba tres métodos de clase, donde respectivamente:
// a. Devuelva lo pedido por el mecanismo de retorno de un método en Java ("return").
// b. Devuelva lo pedido interactuando con algún parámetro (el parámetro no puede ser de tipo arreglo).
// c. Devuelva lo pedido sin usar parámetros ni la sentencia "return".

// %%
// Resolución Ejercicio 5
public class Ejercicio5 {
    public static void main(String[] args) {
        // Tu código aquí
    }
}

// %% [markdown]
// ---
//
// ### Ejercicio 6
// Análisis de las estructuras de listas provistas por la API de Java.
// a. ¿En qué casos ArrayList ofrece un mejor rendimiento que LinkedList?
// b. ¿Cuándo LinkedList puede ser más eficiente que ArrayList?
// c. ¿Qué diferencia encuentra en el uso de la memoria en ArrayList y LinkedList?
// d. ¿En qué casos sería preferible usar un ArrayList o un LinkedList?

// %%
// Resolución Ejercicio 6
/*
 a. 
 b. 
 c. 
 d. 
*/

// %% [markdown]
// ---
//
// ### Ejercicio 7
// Uso de las estructuras de listas provistas por la API de Java.
// a. Escriba una clase llamada `TestArrayList` cuyo método main recibe una secuencia de números, los agrega a una lista de tipo ArrayList, y luego imprime el contenido.
// b. Si hubiera usado LinkedList ¿Qué diferencia encuentra? Justifique.
// c. ¿Existen otras alternativas para recorrer los elementos de la lista?
// d. Escriba un método que realice las siguientes acciones:
//    - cree una lista que contenga 3 estudiantes
//    - genere una nueva lista que sea una copia de la lista del inciso i
//    - imprima el contenido de la lista original y el contenido de la nueva lista
//    - modifique algún dato de los estudiantes
//    - vuelva a imprimir el contenido de la lista original y el contenido de la nueva lista. ¿Qué conclusiones obtiene a partir de lo realizado?
//    - ¿Cuántas formas de copiar una lista existen? ¿Qué diferencias existen entre ellas?
// e. A la lista del punto 7d, agregue un nuevo estudiante. Antes de agregar, verifique que el estudiante no estaba incluido en la lista.
// f. Escriba un método que devuelva verdadero o falso si la secuencia almacenada en la lista es o no capicúa.
// g. Escriba un programa recursivo que calcule la sucesión f(n).
// h. Implemente un método recursivo que invierta un ArrayList.
// i. Implemente un método recursivo que calcule la suma de los elementos en un LinkedList.
// j. Implemente el método “combinarOrdenado” que reciba 2 listas ordenadas y devuelva una nueva combinada y ordenada.

// %%
// Resolución Ejercicio 7
import java.util.ArrayList;
import java.util.LinkedList;
import java.util.List;

public class TestArrayList {
    public static void main(String[] args) {
        // Tu código aquí
    }
}

// %% [markdown]
// ---
//
// ### Ejercicio 8
// Implemente las siguientes clases de acuerdo con la especificación dada en el diagrama de la práctica (paquete tp1.ejercicio8):
// a. Implemente la clase `Queue`.
// b. Implemente la clase `CircularQueue`.
// c. Implemente la clase `DoubleEndedQueue`.

// %%
// Resolución Ejercicio 8
public class Queue<T> {
    // Tu código aquí
}

// %% [markdown]
// ---
//
// ### Ejercicio 9
// Considere un string de caracteres S, el cual comprende únicamente los caracteres: `(,),[,],{,}`. Decimos que S está balanceado si tiene alguna de las formas correctas de apertura y cierre.
// a. Indique qué estructura de datos utilizará para resolver este problema y cómo la utilizará.
// b. Implemente una clase llamada `tp1.ejercicio9.TestBalanceo`, cuyo objetivo es determinar si un String dado está balanceado.

// %%
// Resolución Ejercicio 9
public class TestBalanceo {
    public static void main(String[] args) {
        // Tu código aquí
    }
}

// %% [markdown]
// ---
//
// ### Ejercicio 10 y 11 (Teóricos)
// **10.** Considere el siguiente problema: Se quiere modelar la cola de atención en un banco. ¿Qué estructura de datos sugeriría para el modelado de la cola del banco priorizando la Ley 14564 (prioridad embarazadas, movilidad reducida, mayores 70 años)?
// **11.** Considere el siguiente problema: Se quiere modelar el transporte público de la ciudad de La Plata (líneas de colectivos y paradas fijas). ¿Qué estructura de datos sugeriría para el modelado de las paradas de una línea de colectivos?

// %%
// Resolución Ejercicios 10 y 11
/*
 Ejercicio 10:
 
 Ejercicio 11:
*/
